# %%
print("Hello hello my name is lukas rueda, I am really excited for this class! Please take a look at my derivatives ML project!")
# Out:
# Hello hello my name is lukas rueda, I am really excited for this class! Please take a look at my derivatives ML project!

# %%
import pandas as pd
import numpy as np
import scipy
import sys
print(sys.version)
# Out:
# 3.12.3 (main, Aug 14 2025, 17:47:21) [GCC 13.3.0]
